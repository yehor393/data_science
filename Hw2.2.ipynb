# %%
import os
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Прочитайте файл 2017_jun_final.csv за допомогою методу read_csv

# %%
#         https://docs.google.com/spreadsheets/d/1bclX5PbqE8zR1-wOSM3ZTFa53sIC7RXqwty7Abmw9yQ/edit#gid=1724592523
source = "https://docs.google.com/spreadsheets/d/1bclX5PbqE8zR1-wOSM3ZTFa53sIC7RXqwty7Abmw9yQ/export?format=csv&gid=1724592523"
df = pd.read_csv(source)

# %% [markdown]
# # Прочитайте отриману таблицю, використовуючи метод head

# %%
df.head(5)
# Out:
#    N                    Посада Мова програмування Спеціалізація  \
# 0  1        Junior QA engineer                NaN     Manual QA
# 1  2        Junior QA engineer                NaN     Manual QA
# 2  3         Software Engineer            C#/.NET           NaN
# 3  4         Software Engineer         JavaScript           NaN
# 4  5  Senior Software Engineer         JavaScript           NaN
#
#   Загальний досвід роботи Досвід роботи на поточному місці  \
# 0                     0.5                              0.5
# 1         менше 3 місяців                  менше 3 місяців
# 2                       4                                1
# 3                       5                                4
# 4       10 і більше років                              0.5
#
#    Зарплата на місяць  Зміна зарплати за 12 місяців   Місто   Розмір компанії  \
# 0                 400                             0  Харків        до 10 осіб
# 1                 430                           130  Харків  більше 1000 осіб
# 2                2500                           800    Київ      до 1000 осіб
# 3                2000                           400   Одеса       до 200 осіб
# 4                4500                           500    Інше        до 10 осіб
#
#    ... Ще студент                    Рівень англійської  \
# 0  ...       True    Pre-intermediate (нище середнього)
# 1  ...       True  Upper-Intermediate (вище середнього)
# 2  ...      False               Intermediate (середній)
# 3  ...      False    Pre-intermediate (нище середнього)
# 4  ...      False               Intermediate (середній)
#
#                    Предметна область      Дата заповнення  \
# 0                      iOS,eCommerce  12/06/2017 12:38:08
# 1                       Веб-розробка  12/06/2017 12:42:51
# 2  Веб-розробка,Корпоративні системи  12/06/2017 13:02:47
# 3  Desktop Applications,Веб-розробка  12/06/2017 13:03:01
# 4  Desktop Applications,Веб-розробка  12/06/2017 13:03:47
#
#                                           User.Agent   exp current_job_exp  \
# 0  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   0.5             0.5
# 1  Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS X...   0.0             0.0
# 2  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   4.0             1.0
# 3  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   5.0             4.0
# 4  Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...  10.0             0.5
#
#   salary Валюта  cls
# 0    400    NaN   QA
# 1    430    NaN   QA
# 2   2500    NaN  DEV
# 3   2000    NaN  DEV
# 4   4500    NaN  DEV
#
# [5 rows x 25 columns]

# %% [markdown]
# # Визначте розмір таблиці за допомогою методу shape

# %%
df.shape
# Out:
# (8704, 25)

# %% [markdown]
# # Визначте типи всіх стовпців за допомогою dataframe.dtypes

# %%
df.dtypes
# Out:
# N                                     int64
# Посада                               object
# Мова програмування                   object
# Спеціалізація                        object
# Загальний досвід роботи              object
# Досвід роботи на поточному місці     object
# Зарплата на місяць                    int64
# Зміна зарплати за 12 місяців          int64
# Місто                                object
# Розмір компанії                      object
# Тип компанії                         object
# Стать                                object
# Вік                                   int64
# Освіта                               object
# Університет                          object
# Ще студент                             bool
# Рівень англійської                   object
# Предметна область                    object
# Дата заповнення                      object
# User.Agent                           object
# exp                                 float64
# current_job_exp                     float64
# salary                                int64
# Валюта                               object
# cls                                  object
# dtype: object

# %% [markdown]
# # Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)

# %%
df_columns = df.columns
for columns in df_columns:
    nan_values = (df[columns].isnull().sum()/len(df))*100
    if nan_values > 0:
        print(f"{columns}: {round(nan_values, 2)} %")
# Out:
# Мова програмування: 44.23 %
# Спеціалізація: 82.94 %
# Університет: 4.11 %
# Предметна область: 2.56 %
# Валюта: 99.89 %
# cls: 18.08 %

# %% [markdown]
# # Видаліть усі стовпці з пропусками, крім стовпця "Мова програмування"

# %%
language_column = df[['Мова програмування']]

df_cleaned = df.drop(columns=['Мова програмування']).dropna(axis=1)

df = pd.concat([language_column, df_cleaned], axis=1)
df
# Out:
#      Мова програмування     N                    Посада  \
# 0                   NaN     1        Junior QA engineer
# 1                   NaN     2        Junior QA engineer
# 2               C#/.NET     3         Software Engineer
# 3            JavaScript     4         Software Engineer
# 4            JavaScript     5  Senior Software Engineer
# ...                 ...   ...                       ...
# 8699                NaN  8700               QA engineer
# 8700                NaN  8701                 Marketing
# 8701         Ruby/Rails  8702  Junior Software Engineer
# 8702                NaN  8703                 Team lead
# 8703               Java  8704  Senior Software Engineer
#
#      Загальний досвід роботи Досвід роботи на поточному місці  \
# 0                        0.5                              0.5
# 1            менше 3 місяців                  менше 3 місяців
# 2                          4                                1
# 3                          5                                4
# 4          10 і більше років                              0.5
# ...                      ...                              ...
# 8699                       1                  менше 3 місяців
# 8700                     0.5                              0.5
# 8701                       1                              0.5
# 8702                       6                                4
# 8703                       7                                2
#
#       Зарплата на місяць  Зміна зарплати за 12 місяців   Місто  \
# 0                    400                             0  Харків
# 1                    430                           130  Харків
# 2                   2500                           800    Київ
# 3                   2000                           400   Одеса
# 4                   4500                           500    Інше
# ...                  ...                           ...     ...
# 8699                 700                           700   Одеса
# 8700                 400                           120    Київ
# 8701                 800                           500   Львів
# 8702                2600                             0  Дніпро
# 8703                5000                           800   Одеса
#
#        Розмір компанії   Тип компанії     Стать  Вік             Освіта  \
# 0           до 10 осіб  Аутсорсингова    жіноча   20       Неповна Вища
# 1     більше 1000 осіб  Аутсорсингова    жіноча   21       Неповна Вища
# 2         до 1000 осіб  Аутсорсингова  чоловіча   26               Вища
# 3          до 200 осіб     Продуктова  чоловіча   30            Середня
# 4           до 10 осіб     Продуктова  чоловіча   30  Технікум / Коледж
# ...                ...            ...       ...  ...                ...
# 8699        до 50 осіб  Аутсорсингова  чоловіча   23               Вища
# 8700        до 50 осіб     Продуктова    жіноча   22               Вища
# 8701        до 10 осіб  Аутстафінгова  чоловіча   30       Неповна Вища
# 8702  більше 1000 осіб  Аутсорсингова  чоловіча   34               Вища
# 8703      до 1000 осіб     Продуктова  чоловіча   28               Вища
#
#       Ще студент                    Рівень англійської      Дата заповнення  \
# 0           True    Pre-intermediate (нище середнього)  12/06/2017 12:38:08
# 1           True  Upper-Intermediate (вище середнього)  12/06/2017 12:42:51
# 2          False               Intermediate (середній)  12/06/2017 13:02:47
# 3          False    Pre-intermediate (нище середнього)  12/06/2017 13:03:01
# 4          False               Intermediate (середній)  12/06/2017 13:03:47
# ...          ...                                   ...                  ...
# 8699       False               Intermediate (середній)  12/07/2017 15:45:24
# 8700       False    Pre-intermediate (нище середнього)  12/07/2017 17:00:06
# 8701       False  Upper-Intermediate (вище середнього)  12/07/2017 17:32:26
# 8702       False                 Advanced (просунутий)  12/07/2017 18:14:59
# 8703       False  Upper-Intermediate (вище середнього)  12/07/2017 21:28:57
#
#                                              User.Agent   exp  \
# 0     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   0.5
# 1     Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS X...   0.0
# 2     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   4.0
# 3     Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   5.0
# 4     Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...  10.0
# ...                                                 ...   ...
# 8699  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:54....   1.0
# 8700  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   0.5
# 8701  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   1.0
# 8702  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...   6.0
# 8703  Mozilla/5.0 (iPad; CPU OS 10_3_2 like Mac OS X...   7.0
#
#       current_job_exp  salary
# 0                 0.5     400
# 1                 0.0     430
# 2                 1.0    2500
# 3                 4.0    2000
# 4                 0.5    4500
# ...               ...     ...
# 8699              0.0     700
# 8700              0.5     400
# 8701              0.5     800
# 8702              4.0    2600
# 8703              2.0    5000
#
# [8704 rows x 20 columns]

# %% [markdown]
# # Знову порахуйте, яка частка пропусків міститься в кожній колонці і переконайтеся, що залишився тільки стовпець "Мова.програмування"

# %%
df_columns = df.columns
for columns in df_columns:
    nan_values = (df[columns].isnull().sum()/len(df))*100
    if nan_values > 0:
        print(f"{columns}: {round(nan_values, 2)} %")
# Out:
# Мова програмування: 44.23 %

# %% [markdown]
# # Видаліть усі рядки у вихідній таблиці за допомогою методу dropna

# %%
df = df.dropna(axis=0).reset_index(drop=True)

# %% [markdown]
# # Визначте новий розмір таблиці за допомогою методу shape

# %%
df.shape
# Out:
# (4854, 20)

# %%
# Припускаємо, у вас є DataFrame df, і колонка з мовами програмування називається 'Мова програмування'
language_counts = df['Мова програмування'].value_counts()

# Після цього ви можете продовжити зі створенням графіка
plt.figure(figsize=(14, 8))
palette_colors = sns.color_palette('viridis', n_colors=len(language_counts))
plt.bar(language_counts.index, language_counts.values, color=palette_colors)

plt.title('Кількість мов програмування', fontsize=16)
plt.xlabel('Мова програмування', fontsize=14)
plt.ylabel('Кількість', fontsize=14)

for i, count in enumerate(language_counts.values):
    plt.text(i, count, str(count), ha='center', va='bottom')

sns.despine()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Створіть нову таблицю python_data, в якій будуть тільки рядки зі спеціалістами, які вказали мову програмування Python

# %%
python_data = df[df['Мова програмування'] == 'Python'].reset_index(drop=True)
python_data
# Out:
#     Мова програмування     N                    Посада  \
# 0               Python    13         Software Engineer
# 1               Python    69         Software Engineer
# 2               Python    88  Junior Software Engineer
# 3               Python   115  Junior Software Engineer
# 4               Python   144  Junior Software Engineer
# ..                 ...   ...                       ...
# 202             Python  8547         Software Engineer
# 203             Python  8626         Software Engineer
# 204             Python  8636  Senior Software Engineer
# 205             Python  8674  Junior Software Engineer
# 206             Python  8696         Software Engineer
#
#     Загальний досвід роботи Досвід роботи на поточному місці  \
# 0                         1                  менше 3 місяців
# 1                       1.5                              0.5
# 2                       0.5                              0.5
# 3                       1.5                              0.5
# 4                         1                                1
# ..                      ...                              ...
# 202                       5                                1
# 203                       4                                1
# 204       10 і більше років                  менше 3 місяців
# 205                     0.5                              0.5
# 206                       1                              0.5
#
#      Зарплата на місяць  Зміна зарплати за 12 місяців      Місто  \
# 0                   800                           200       Київ
# 1                   900                           900       Київ
# 2                   600                             0       Київ
# 3                   685                           250       Київ
# 4                   750                           250       Київ
# ..                  ...                           ...        ...
# 202                2000                           800  Запоріжжя
# 203                1750                             0       Київ
# 204                4000                          1300  Віддалено
# 205                 350                            50       Київ
# 206                1500                          1000       Київ
#
#       Розмір компанії   Тип компанії     Стать  Вік        Освіта  Ще студент  \
# 0          до 50 осіб  Аутсорсингова  чоловіча   26          Вища       False
# 1          до 10 осіб        Стартап  чоловіча   21  Неповна Вища        True
# 2          до 10 осіб  Аутсорсингова  чоловіча   19  Неповна Вища        True
# 3        до 1000 осіб  Аутсорсингова  чоловіча   21  Неповна Вища       False
# 4          до 10 осіб  Аутсорсингова  чоловіча   21  Неповна Вища        True
# ..                ...            ...       ...  ...           ...         ...
# 202        до 50 осіб  Аутсорсингова  чоловіча   22  Неповна Вища       False
# 203  більше 1000 осіб  Аутсорсингова  чоловіча   28       Середня       False
# 204        до 10 осіб        Стартап  чоловіча   33          Вища       False
# 205        до 50 осіб  Аутсорсингова  чоловіча   22          Вища       False
# 206        до 10 осіб        Стартап  чоловіча   29          Вища       False
#
#                        Рівень англійської      Дата заповнення  \
# 0      Pre-intermediate (нище середнього)  12/06/2017 13:05:54
# 1    Upper-Intermediate (вище середнього)  12/06/2017 13:11:17
# 2    Upper-Intermediate (вище середнього)  12/06/2017 13:12:25
# 3                 Intermediate (середній)  12/06/2017 13:14:52
# 4    Upper-Intermediate (вище середнього)  12/06/2017 13:19:10
# ..                                    ...                  ...
# 202               Intermediate (середній)  10/07/2017 14:11:26
# 203               Intermediate (середній)  11/07/2017 16:15:40
# 204  Upper-Intermediate (вище середнього)  11/07/2017 17:51:36
# 205               Intermediate (середній)   12/07/2017 9:37:16
# 206               Intermediate (середній)  12/07/2017 14:39:21
#
#                                             User.Agent   exp  current_job_exp  \
# 0    Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   1.0              0.0
# 1    Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   1.5              0.5
# 2    Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   0.5              0.5
# 3    Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   1.5              0.5
# 4    Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   1.0              1.0
# ..                                                 ...   ...              ...
# 202  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5...   5.0              1.0
# 203  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:54....   4.0              1.0
# 204  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...  10.0              0.0
# 205  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:54....   0.5              0.5
# 206  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   1.0              0.5
#
#      salary
# 0       800
# 1       900
# 2       600
# 3       685
# 4       750
# ..      ...
# 202    2000
# 203    1750
# 204    4000
# 205     350
# 206    1500
#
# [207 rows x 20 columns]

# %% [markdown]
# # Визначте розмір таблиці python_data за допомогою методу shape

# %%
python_data.shape
# Out:
# (207, 20)

# %% [markdown]
# # Використовуючи метод groupby, виконайте групування за стовпчиком "Посада"

# %%
position = python_data.groupby(['Посада'])

# %% [markdown]
# # Створіть новий DataFrame, де для згрупованих даних за стовпчиком "Посада", виконайте агрегацію даних за допомогою методу agg і знайдіть мінімальне та максимальне значення у стовпчику "Зарплата.в.місяць"

# %%
new_df = position.agg({'Зарплата на місяць' : ['min', 'max']})
new_df
# Out:
#                          Зарплата на місяць
#                                         min   max
# Посада
# Junior Software Engineer                100  1250
# Senior Software Engineer               1300  9200
# Software Engineer                       500  5400
# System Architect                       3000  5000
# Technical Lead                         1425  6200

# %% [markdown]
# # Створіть функцію fill_avg_salary, яка повертатиме середнє значення заробітної плати на місяць. Використовуйте її для методу apply та створіть новий стовпчик "avg"

# %%
# def fill_avg_salary(row):
#     return (row[('Зарплата на місяць', 'min')] + row[('Зарплата на місяць', 'max')]) / 2

# new_df['Зарплата на місяць', 'avg'] = new_df.apply(fill_avg_salary, axis=1)

def fill_avg_salary(row):
    return (row.iat[0] + row.iat[1]) / 2

new_df['Зарплата на місяць', 'avg'] = new_df.apply(fill_avg_salary, axis=1)

new_df
# Out:
#                          Зарплата на місяць
#                                         min   max     avg
# Посада
# Junior Software Engineer                100  1250   675.0
# Senior Software Engineer               1300  9200  5250.0
# Software Engineer                       500  5400  2950.0
# System Architect                       3000  5000  4000.0
# Technical Lead                         1425  6200  3812.5

# %%
positions = new_df.index

min_salaries = new_df['Зарплата на місяць', 'min']
max_salaries = new_df['Зарплата на місяць', 'max']
avg_salaries = new_df['Зарплата на місяць', 'avg']

plt.figure(figsize=(10, 8))

x = np.arange(len(positions))

bar_width = 0.25

plt.bar(x - bar_width, min_salaries, width=bar_width, label='Мінімум', edgecolor='black')
plt.bar(x, max_salaries, width=bar_width, label='Максимум', edgecolor='black')
plt.bar(x + bar_width, avg_salaries, width=bar_width, label='Середнє', edgecolor='black')

plt.title('Зарплати за посадами', fontsize=16, fontweight='bold')
plt.xlabel('Посада', fontsize=14)
plt.ylabel('Зарплата (у валюті)', fontsize=14)

plt.legend()

plt.xticks(ticks=x, labels=positions, rotation=45, ha='right')

plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()

plt.show()

# %% [markdown]
# # Створіть описову статистику за допомогою методу describe для нового стовпчика.

# %%
desc_stats = new_df['Зарплата на місяць', 'avg'].describe()

print(desc_stats)
# Out:
# count       5.000000
# mean     3337.500000
# std      1700.091909
# min       675.000000
# 25%      2950.000000
# 50%      3812.500000
# 75%      4000.000000
# max      5250.000000
# Name: (Зарплата на місяць, avg), dtype: float64

# %% [markdown]
# # Збережіть отриману таблицю в CSV файл

# %%
new_df.to_csv("Salary.csv", index = False)
new_df.to_excel("Salary.xlsx")
desc_stats.to_csv("desc_stats.csv", index = False)
